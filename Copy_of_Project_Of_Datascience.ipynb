# %% [markdown]
# <a href="https://colab.research.google.com/github/Monika-coder1/Data-Science-Project/blob/main/Copy_of_Project_Of_Datascience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('/content/train.csv')
df2 = pd.read_csv('/content/store.csv')
# Out:
# <ipython-input-15-1c2b39781610>:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('/content/train.csv')

# %%
df1.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
df2.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
df1.shape
# Out:
# (1017209, 9)

# %%
df1.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')

# %%
df2.shape
# Out:
# (1115, 10)

# %%
df2.columns
# Out:
# Index(['Store', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
combined_df = pd.concat([df1,df2],axis=1)

# %%
combined_df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday  Store StoreType Assortment  CompetitionDistance  \
# 0              1    1.0         c          a               1270.0
# 1              1    2.0         a          a                570.0
# 2              1    3.0         a          a              14130.0
# 3              1    4.0         c          c                620.0
# 4              1    5.0         a          a              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# ...

# %%
combined_df.shape
# Out:
# (1017209, 19)

# %%
combined_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'Store', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
combined_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
combined_df.isnull().sum()
# Out:
# Store                              0
# DayOfWeek                          0
# Date                               0
# Sales                              0
# Customers                          0
# Open                               0
# Promo                              0
# StateHoliday                       0
# SchoolHoliday                      0
# Store                        1016094
# StoreType                    1016094
# Assortment                   1016094
# CompetitionDistance          1016097
# CompetitionOpenSinceMonth    1016448
# CompetitionOpenSinceYear     1016448
# Promo2                       1016094
# Promo2SinceWeek              1016638
# Promo2SinceYear              1016638
# PromoInterval                1016638
# dtype: int64

# %%
combined_df['Store'] = combined_df[['Store','Store']].sum(axis=1)

# %%
combined_df.drop('Store',axis=1,inplace=True)

# %%
combined_df.head()
# Out:
#    DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0          5  2015-07-31   5263        555     1      1            0
# 1          5  2015-07-31   6064        625     1      1            0
# 2          5  2015-07-31   8314        821     1      1            0
# 3          5  2015-07-31  13995       1498     1      1            0
# 4          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0     0.0
# 1                       11.0                    2007.0     1.0
# ...

# %%
combined_df.columns
# Out:
# Index(['DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
combined_df.isnull().sum()
# Out:
# DayOfWeek                          0
# Date                               0
# Sales                              0
# Customers                          0
# Open                               0
# Promo                              0
# StateHoliday                       0
# SchoolHoliday                      0
# StoreType                    1016094
# Assortment                   1016094
# CompetitionDistance          1016097
# CompetitionOpenSinceMonth    1016448
# CompetitionOpenSinceYear     1016448
# Promo2                       1016094
# Promo2SinceWeek              1016638
# Promo2SinceYear              1016638
# PromoInterval                1016638
# dtype: int64

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   DayOfWeek                  1017209 non-null  int64
#  1   Date                       1017209 non-null  object
#  2   Sales                      1017209 non-null  int64
#  3   Customers                  1017209 non-null  int64
#  4   Open                       1017209 non-null  int64
#  5   Promo                      1017209 non-null  int64
#  6   StateHoliday               1017209 non-null  object
#  7   SchoolHoliday              1017209 non-null  int64
#  8   StoreType                  1115 non-null     object
#  9   Assortment                 1115 non-null     object
#  10  CompetitionDistance        1112 non-null     float64
#  11  CompetitionOpenSinceMonth  761 non-null      float64
#  12  CompetitionOpenSinceYear   761 non-null      float64
# ...

# %%
combined_df.dropna(subset=['StoreType'])
# Out:
#       DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0             5  2015-07-31   5263        555     1      1            0
# 1             5  2015-07-31   6064        625     1      1            0
# 2             5  2015-07-31   8314        821     1      1            0
# 3             5  2015-07-31  13995       1498     1      1            0
# 4             5  2015-07-31   4822        559     1      1            0
# ...         ...         ...    ...        ...   ...    ...          ...
# 1110          5  2015-07-31   5723        422     1      1            0
# 1111          5  2015-07-31   9626        767     1      1            0
# 1112          5  2015-07-31   7289        720     1      1            0
# 1113          5  2015-07-31  27508       3745     1      1            0
# 1114          5  2015-07-31   8680        538     1      1            0
#
#       SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
combined_df.groupby('StoreType')['Sales'].mean()
# Out:
# StoreType
# a     8937.468439
# b    12677.764706
# c     9109.317568
# d     9096.795977
# Name: Sales, dtype: float64

# %%
combined_df.groupby('StoreType')['Sales'].max()
# Out:
# StoreType
# a    27508
# b    25774
# c    18690
# d    23996
# Name: Sales, dtype: int64

# %%
combined_df.groupby('StoreType')['Sales'].min()
# Out:
# StoreType
# a       0
# b    6975
# c    3377
# d    4239
# Name: Sales, dtype: int64

# %%
combined_df.groupby('StoreType')['Sales'].sum()
# Out:
# StoreType
# a    5380356
# b     215522
# c    1348179
# d    3165685
# Name: Sales, dtype: int64

# %%
combined_df.columns
# Out:
# Index(['DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
combined_df.groupby(['StoreType','CompetitionOpenSinceMonth','CompetitionOpenSinceYear'])['Sales'].sum()
# Out:
# StoreType  CompetitionOpenSinceMonth  CompetitionOpenSinceYear
# a          1.0                        1900.0                       8186
#                                       2005.0                      44780
#                                       2007.0                       4209
#                                       2008.0                       7972
#                                       2011.0                       8350
#                                                                   ...
# d          12.0                       2007.0                      22225
#                                       2008.0                       7947
#                                       2010.0                      18914
#                                       2013.0                      18519
#                                       2014.0                      37605
# Name: Sales, Length: 335, dtype: int64

# %%
pivot = combined_df.pivot_table(index=['StoreType', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear'],values='Sales',aggfunc='sum'
)

# %%
pivot.head(20)
# Out:
#                                                               Sales
# StoreType CompetitionOpenSinceMonth CompetitionOpenSinceYear
# a         1.0                       1900.0                     8186
#                                     2005.0                    44780
#                                     2007.0                     4209
#                                     2008.0                     7972
#                                     2011.0                     8350
#           2.0                       2002.0                    29435
#                                     2004.0                     5012
#                                     2005.0                    21711
#                                     2006.0                    11035
#                                     2008.0                    21072
#                                     2009.0                    12253
#                                     2010.0                    67324
# ...

# %%
combined_df.groupby(['CompetitionDistance'])['Sales'].sum()
# Out:
# CompetitionDistance
# 20.0        7303
# 30.0       27993
# 40.0       42333
# 50.0       93378
# 60.0       38185
#            ...
# 45740.0    10708
# 46590.0     6058
# 48330.0     7460
# 58260.0    12336
# 75860.0    13328
# Name: Sales, Length: 654, dtype: int64

# %%
combined_df.columns
# Out:
# Index(['DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
combined_df.groupby(['StateHoliday','SchoolHoliday'])['Sales'].sum()
# Out:
# StateHoliday  SchoolHoliday
# 0             0                 544107318
#               1                 207398008
#               0                4146934207
#               1                 966725235
# a             0                   5010319
#               1                    879986
# b             0                    208687
#               1                   1225057
# c             1                    691806
# Name: Sales, dtype: int64

# %%
combined_df.groupby(['StoreType','Customers','CompetitionOpenSinceMonth'])['Sales'].sum()
# Out:
# StoreType  Customers  CompetitionOpenSinceMonth
# a          0          4.0                              0
#                       6.0                              0
#            327        12.0                          2726
#            358        6.0                           3648
#            377        9.0                           3419
#                                                    ...
# d          1184       4.0                          12620
#            1225       4.0                          13399
#                       8.0                          10520
#            1228       3.0                          12887
#            1362       11.0                         23996
# Name: Sales, Length: 740, dtype: int64

# %%
sns.boxplot(x='StoreType',y='Sales',data=combined_df)
# Out:
# <Axes: xlabel='StoreType', ylabel='Sales'>

# %%
sns.countplot(x='StoreType',hue= 'Promo2SinceYear',data=combined_df)
# Out:
# <Axes: xlabel='StoreType', ylabel='count'>

# %%
sns.barplot(x='StateHoliday',y='SchoolHoliday',data=combined_df)
# Out:
# <Axes: xlabel='StateHoliday', ylabel='SchoolHoliday'>
